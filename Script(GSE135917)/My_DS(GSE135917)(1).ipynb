# %%
import pandas as pd
from sklearn.feature_selection import SelectFromModel
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.feature_selection import SelectFromModel
from sklearn.linear_model import LogisticRegression as LR
from sklearn.model_selection import train_test_split
import numpy as np
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_val_score
from sklearn.metrics import accuracy_score
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc

# %%
df = pd.read_csv('C:\\Users\\hemanth\\desktop\\OSA_ML\\Original\\3)ML\\GSE135917\\exps(GSE135917).txt',sep='\t')
df = df.set_index('ID')
df = df.T
df.to_csv('exp.txt', sep='\t')

# %%
df
# Out:
# ID            BTN3A2        RAN  EIF5AL1///EIF5A      PIGK   HLA-DRB5  \
# GSM4037879  8.101242   9.118345        10.372940  6.853071   7.505383
# GSM4037880  7.543268   9.409455        10.297990  7.052034   8.286639
# GSM4037881  6.554783   9.063534         9.993797  6.633845   7.086667
# GSM4037882  7.674518   9.660094        10.337850  7.297116   7.689629
# GSM4037883  7.002152   9.182082         9.698058  6.358088   7.434511
# GSM4037884  7.226961   8.898132         9.312602  6.401828   7.421490
# GSM4037885  7.486697   9.397806        10.371950  6.801425   7.938261
# GSM4037886  7.949981   9.532534        10.072760  6.384011   7.746600
# GSM4037887  7.808005   9.476140        10.581440  7.195648   8.078850
# GSM4037888  8.121639   9.909078        10.863800  7.566715  10.052680
# GSM4037889  8.068334   9.667414        10.571350  6.989554   9.403235
# GSM4037890  8.430242   9.416754        10.486310  7.014357   8.518600
# ...

# %%
l = pd.read_csv('C:\\Users\\hemanth\\desktop\\OSA_ML\\Original\\3)ML\\GSE135917\\s(GSE135917).txt',sep='\t')
l
# Out:
#          index  label
# 0   GSM4037879      0
# 1   GSM4037880      0
# 2   GSM4037881      0
# 3   GSM4037882      0
# 4   GSM4037883      0
# 5   GSM4037884      0
# 6   GSM4037885      0
# 7   GSM4037886      0
# 8   GSM4037887      1
# 9   GSM4037888      1
# 10  GSM4037889      1
# 11  GSM4037890      1
# 12  GSM4037891      1
# 13  GSM4037892      1
# 14  GSM4037893      1
# 15  GSM4037894      1
# 16  GSM4037895      1
# 17  GSM4037896      1

# %%
df1 = df.reset_index()
df2 = pd.merge(l,df1,how='inner',on='index')
df2
# Out:
#          index  label    BTN3A2        RAN  EIF5AL1///EIF5A      PIGK  \
# 0   GSM4037879      0  8.101242   9.118345        10.372940  6.853071
# 1   GSM4037880      0  7.543268   9.409455        10.297990  7.052034
# 2   GSM4037881      0  6.554783   9.063534         9.993797  6.633845
# 3   GSM4037882      0  7.674518   9.660094        10.337850  7.297116
# 4   GSM4037883      0  7.002152   9.182082         9.698058  6.358088
# 5   GSM4037884      0  7.226961   8.898132         9.312602  6.401828
# 6   GSM4037885      0  7.486697   9.397806        10.371950  6.801425
# 7   GSM4037886      0  7.949981   9.532534        10.072760  6.384011
# 8   GSM4037887      1  7.808005   9.476140        10.581440  7.195648
# 9   GSM4037888      1  8.121639   9.909078        10.863800  7.566715
# 10  GSM4037889      1  8.068334   9.667414        10.571350  6.989554
# 11  GSM4037890      1  8.430242   9.416754        10.486310  7.014357
# ...

# %%
pd.DataFrame(df2['label']).to_csv('label.txt',sep='\t',index=False)

# %%
data = pd.read_csv('exp.txt',sep='\t')
data = data.set_index('Unnamed: 0')
def mean_norm(df_input):
    return df_input.apply(lambda x: (x-x.mean())/ x.std(), axis=0)
data = mean_norm(data)
target = pd.read_csv('label.txt',sep='\t')

# %%
data
# Out:
#               BTN3A2       RAN  EIF5AL1///EIF5A      PIGK  HLA-DRB5     YWHAE  \
# Unnamed: 0
# GSM4037879  0.727625 -1.209141         0.052935 -0.436717 -0.802996 -0.560318
# GSM4037880 -0.436552 -0.442254        -0.128473 -0.010031  0.188906 -0.028059
# GSM4037881 -2.498962 -1.353533        -0.864738 -0.906858 -1.334608 -0.492159
# GSM4037882 -0.162707  0.218018        -0.031997  0.515559 -0.569073  0.312090
# GSM4037883 -1.565555 -1.041235        -1.580540 -1.498232 -0.892977 -1.417665
# GSM4037884 -1.096506 -1.789260        -2.513492 -1.404429 -0.909509 -2.465649
# GSM4037885 -0.554584 -0.472942         0.050538 -0.547474 -0.253403 -0.283583
# GSM4037886  0.412028 -0.118020        -0.673617 -1.442639 -0.496741 -0.063174
# GSM4037887  0.115805 -0.266582         0.557585  0.297956 -0.074908  0.240678
# GSM4037888  0.770182  0.873930         1.241005  1.093727  2.431117  0.751971
# GSM4037889  0.658964  0.237302         0.533163 -0.144023  1.606565  0.310464
# ...

# %%
x_train,x_test, y_train, y_test = train_test_split(data,target,test_size=0.2, random_state=0)
x_train = x_train.T
x_train.to_csv('x_train.csv')
x_test.to_csv('x_test.csv')
y_train.to_csv('y_train.csv',index=False)
y_test.to_csv('y_test.csv',index=False)

# %%
test = pd.read_csv('C:\\Users\\hemanth\\desktop\\OSA_ML\\Original\\3)ML\\GSE135917\\expss(GSE135917).txt',sep='\t')
test = test.set_index('geneNames')
test = test.T
test
# Out:
# geneNames     BTN3A2        RAN  EIF5AL1///EIF5A      PIGK   HLA-DRB5  \
# GSM4037879  8.101242   9.118345        10.372940  6.853071   7.505383
# GSM4037880  7.543268   9.409455        10.297990  7.052034   8.286639
# GSM4037881  6.554783   9.063534         9.993797  6.633845   7.086667
# GSM4037882  7.674518   9.660094        10.337850  7.297116   7.689629
# GSM4037883  7.002152   9.182082         9.698058  6.358088   7.434511
# GSM4037884  7.226961   8.898132         9.312602  6.401828   7.421490
# GSM4037885  7.486697   9.397806        10.371950  6.801425   7.938261
# GSM4037886  7.949981   9.532534        10.072760  6.384011   7.746600
# GSM4037887  7.808005   9.476140        10.581440  7.195648   8.078850
# GSM4037888  8.121639   9.909078        10.863800  7.566715  10.052680
# GSM4037889  8.068334   9.667414        10.571350  6.989554   9.403235
# GSM4037890  8.430242   9.416754        10.486310  7.014357   8.518600
# ...

# %%
feature_importance = pd.read_csv('C:\\Users\\hemanth\\desktop\\OSA_ML\\Original\\3)ML\\GSE135917\\data_all_merge_RF(GSE135917).csv')
feature_importance
feature_list = feature_importance['ID']
feature_list = feature_list[:26]
feature_list = feature_list[:26]
test.to_csv('test.txt',sep='\t')
